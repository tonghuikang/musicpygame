# %%
# basically this means `import note_evaluation_helper`
# %run 'note_evaluation_helper.ipynb'

# %% [markdown]
# # Regression model for note splitting

# %%
import numpy as np
import soundfile as sf
import statsmodels.api as sm
import pandas as pd
# Out:
# /anaconda3/envs/mir/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
def lg_regression(signal_to_ayse):

#     filename = 'C4_61_64_67_71.wav'

    #number of keys (should be 12) to be considered here
    num_notes = 12

    #level of significance
    alpha = 0.00001

    # assuming that we have 12 vectors of length 4096: A,A_sharp,B.......G_sharp
    #these are the fourier transforms of the notes
    # then we can make a matrix X, with the columns as these notes

    #X is a 2048 by 12 matrix
    X = np.zeros((2048,num_notes))


    #reading the sound file

    for i in range(12):
        ref, sample_rate = sf.read('soundfile_template/C4_' + str(i+60) +'_x_x_x.wav')
        note = np.fft.fft(ref[20000:24096,0]) 
        note_new = note.real[0:int(len(note)/2)]
        X[:,i] = note_new
    


    note = np.fft.fft(signal_to_ayse)
    note_new = note.real[0:int(len(note)/2)]
    Y = note_new
    print(Y)


    # define the predictors and target values in data frames
    x = pd.DataFrame(X)
    y = pd.DataFrame(Y)

    # Note the difference in argument order
    model = sm.OLS(y, x).fit()
    predictions = model.predict(x) # make the predictions by the model

    # Print out the statistics
    print(model.summary())
    
    print("r-squared value: ", model.rsquared)

    involved_notes = []
    for i in range(len(model.pvalues)):
        if model.pvalues[i] < alpha:
            involved_notes.append(i+60)

    print(involved_notes)
#     print("mystery chord is", filename)
    print("degree of significance, alpha is:", alpha)
    
    return involved_notes

# %%
if __name__ == '__main__':
    test_function_accuracy(lg_regression, plotting=False, deleting=True)
# Out:
# 4
# 1
# C4_64_68_69_70
# [-0.07693481  0.10919397 -0.02662418 ... -0.05948248 -0.05903086
#  -0.05964476]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      0   R-squared:                       0.827
# Model:                            OLS   Adj. R-squared:                  0.826
# Method:                 Least Squares   F-statistic:                     810.7
# Date:                Sat, 12 May 2018   Prob (F-statistic):               0.00
# Time:                        21:52:21   Log-Likelihood:                -2641.5
# No. Observations:                2048   AIC:                             5307.
# Df Residuals:                    2036   BIC:                             5375.
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 0             -0.0205      0.022     -0.951      0.342      -0.063       0.022
# 1              0.0233      0.016      1.411      0.158      -0.009       0.056
# 2             -0.3366      0.061     -5.504      0.000      -0.457      -0.217
# 3             -0.9438      0.081    -11.719      0.000      -1.102      -0.786
# 4              0.7293      0.021     33.965      0.000       0.687       0.771
# 5              0.1196      0.030      4.008      0.000       0.061       0.178
# 6              0.0007      0.020      0.036      0.972      -0.039       0.040
# 7             -0.0098      0.028     -0.351      0.726      -0.065       0.045
# 8             -1.3800      0.045    -30.997      0.000      -1.467      -1.293
# 9             -0.5792      0.020    -28.345      0.000      -0.619      -0.539
# 10             2.1180      0.028     75.405      0.000       2.063       2.173
# 11             0.1786      0.029      6.115      0.000       0.121       0.236
# ==============================================================================
# Omnibus:                     1629.523   Durbin-Watson:                   2.089
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1601491.111
# Skew:                          -2.417   Prob(JB):                         0.00
# Kurtosis:                     139.909   Cond. No.                         5.12
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# r-squared value:  0.8269356408147874
# [62, 63, 64, 68, 69, 70, 71]
# degree of significance, alpha is: 1e-05
# --results--
# [64, 68, 69, 70]
# [62, 63, 64, 68, 69, 70, 71]
# ===========
# [4, 7, 4, 3, 0]
# 3
# 1
# C4_64_66_69_x
# [ 0.00054932  0.12758331  0.06173259 ... -0.002226   -0.00163864
#  -0.00151406]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      0   R-squared:                       0.768
# Model:                            OLS   Adj. R-squared:                  0.767
# Method:                 Least Squares   F-statistic:                     562.5
# Date:                Sat, 12 May 2018   Prob (F-statistic):               0.00
# Time:                        21:52:24   Log-Likelihood:                -2355.4
# No. Observations:                2048   AIC:                             4735.
# Df Residuals:                    2036   BIC:                             4802.
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 0             -0.0500      0.019     -2.662      0.008      -0.087      -0.013
# 1              0.0253      0.014      1.762      0.078      -0.003       0.053
# 2              1.2914      0.053     24.285      0.000       1.187       1.396
# 3              0.2040      0.070      2.913      0.004       0.067       0.341
# 4             -0.9634      0.019    -51.597      0.000      -1.000      -0.927
# 5              0.0203      0.026      0.782      0.434      -0.031       0.071
# 6             -0.8131      0.018    -46.295      0.000      -0.848      -0.779
# 7             -0.0368      0.024     -1.508      0.132      -0.085       0.011
# 8              0.0426      0.039      1.100      0.272      -0.033       0.118
# 9             -0.5881      0.018    -33.094      0.000      -0.623      -0.553
# 10            -0.0379      0.024     -1.552      0.121      -0.086       0.010
# 11            -0.0034      0.025     -0.132      0.895      -0.053       0.046
# ==============================================================================
# Omnibus:                     1942.765   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1049007.770
# Skew:                           3.576   Prob(JB):                         0.00
# Kurtosis:                     113.643   Cond. No.                         5.12
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# r-squared value:  0.768277248585444
# [62, 64, 66, 69]
# degree of significance, alpha is: 1e-05
# --results--
# [64, 66, 69]
# [62, 64, 66, 69]
# ===========
# [3, 4, 3, 1, 0]
# 4
# 1
# C4_63_64_66_68
# [-2.0944519  -1.95126742 -2.024113   ...  0.01184175  0.01067054
#   0.01050832]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      0   R-squared:                       0.514
# Model:                            OLS   Adj. R-squared:                  0.511
# Method:                 Least Squares   F-statistic:                     179.4
# Date:                Sat, 12 May 2018   Prob (F-statistic):          4.00e-308
# Time:                        21:52:26   Log-Likelihood:                -3549.4
# No. Observations:                2048   AIC:                             7123.
# Df Residuals:                    2036   BIC:                             7190.
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 0              0.0269      0.034      0.798      0.425      -0.039       0.093
# 1             -0.0185      0.026     -0.719      0.472      -0.069       0.032
# 2              0.0799      0.095      0.839      0.402      -0.107       0.267
# 3              1.9383      0.125     15.450      0.000       1.692       2.184
# 4              0.9115      0.033     27.250      0.000       0.846       0.977
# 5             -0.0216      0.046     -0.465      0.642      -0.113       0.070
# 6              0.5708      0.031     18.140      0.000       0.509       0.632
# 7              0.1190      0.044      2.718      0.007       0.033       0.205
# 8              1.9588      0.069     28.243      0.000       1.823       2.095
# 9             -0.0804      0.032     -2.524      0.012      -0.143      -0.018
# 10             0.1129      0.044      2.581      0.010       0.027       0.199
# 11            -0.1078      0.045     -2.370      0.018      -0.197      -0.019
# ==============================================================================
# Omnibus:                     1838.366   Durbin-Watson:                   1.952
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1764726.746
# Skew:                           3.064   Prob(JB):                         0.00
# Kurtosis:                     146.676   Cond. No.                         5.12
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# r-squared value:  0.5139074101743598
# [63, 64, 66, 68]
# degree of significance, alpha is: 1e-05
# --results--
# [63, 64, 66, 68]
# [63, 64, 66, 68]
# ===========
# [4, 4, 4, 0, 0]
# 4
# 1
# C4_64_65_68_71
# [-1.95153809 -1.82356783 -2.02979146 ...  0.01836959  0.01814528
#   0.01849091]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      0   R-squared:                       0.591
# Model:                            OLS   Adj. R-squared:                  0.588
# Method:                 Least Squares   F-statistic:                     244.8
# Date:                Sat, 12 May 2018   Prob (F-statistic):               0.00
# Time:                        21:52:29   Log-Likelihood:                -3635.4
# No. Observations:                2048   AIC:                             7295.
# Df Residuals:                    2036   BIC:                             7362.
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 0              0.0613      0.035      1.745      0.081      -0.008       0.130
# 1             -0.0204      0.027     -0.763      0.446      -0.073       0.032
# 2              0.0568      0.099      0.572      0.567      -0.138       0.252
# 3              0.0569      0.131      0.435      0.664      -0.200       0.313
# 4              1.0495      0.035     30.088      0.000       0.981       1.118
# 5              1.5701      0.048     32.390      0.000       1.475       1.665
# 6              0.0798      0.033      2.431      0.015       0.015       0.144
# 7             -0.0343      0.046     -0.751      0.453      -0.124       0.055
# 8              2.0580      0.072     28.452      0.000       1.916       2.200
# 9             -0.0884      0.033     -2.664      0.008      -0.154      -0.023
# 10             0.2195      0.046      4.809      0.000       0.130       0.309
# 11            -0.6284      0.047    -13.247      0.000      -0.721      -0.535
# ==============================================================================
# Omnibus:                     2360.601   Durbin-Watson:                   1.884
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1448070.979
# Skew:                           5.154   Prob(JB):                         0.00
# Kurtosis:                     132.859   Cond. No.                         5.12
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# r-squared value:  0.5906541870192169
# [64, 65, 68, 70, 71]
# degree of significance, alpha is: 1e-05
# --results--
# [64, 65, 68, 71]
# [64, 65, 68, 70, 71]
# ===========
# [4, 5, 4, 1, 0]
# 4
# 1
# C4_61_63_69_71
# [-0.50170898 -0.25902006 -0.29515506 ...  0.00505111  0.0057887
#   0.00549378]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      0   R-squared:                       0.797
# Model:                            OLS   Adj. R-squared:                  0.796
# Method:                 Least Squares   F-statistic:                     667.7
# Date:                Sat, 12 May 2018   Prob (F-statistic):               0.00
# Time:                        21:52:31   Log-Likelihood:                -2673.3
# No. Observations:                2048   AIC:                             5371.
# Df Residuals:                    2036   BIC:                             5438.
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 0             -0.0128      0.022     -0.582      0.560      -0.056       0.030
# 1             -0.6720      0.017    -40.144      0.000      -0.705      -0.639
# 2              1.3237      0.062     21.313      0.000       1.202       1.446
# 3             -0.9877      0.082    -12.076      0.000      -1.148      -0.827
# 4              0.1610      0.022      7.383      0.000       0.118       0.204
# 5              0.0436      0.030      1.440      0.150      -0.016       0.103
# 6              0.0543      0.021      2.645      0.008       0.014       0.094
# 7             -0.0120      0.029     -0.419      0.675      -0.068       0.044
# 8             -0.5627      0.045    -12.444      0.000      -0.651      -0.474
# 9             -0.6385      0.021    -30.765      0.000      -0.679      -0.598
# 10            -0.1987      0.029     -6.966      0.000      -0.255      -0.143
# 11             2.0636      0.030     69.591      0.000       2.005       2.122
# ==============================================================================
# Omnibus:                     1921.501   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           826902.507
# Skew:                           3.572   Prob(JB):                         0.00
# Kurtosis:                     101.180   Cond. No.                         5.12
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# r-squared value:  0.7973766771444313
# [61, 62, 63, 64, 68, 69, 70, 71]
# degree of significance, alpha is: 1e-05
# --results--
# [61, 63, 69, 71]
# [61, 62, 63, 64, 68, 69, 70, 71]
# ===========
# [4, 8, 4, 4, 0]
# 4
# 1
# C4_61_62_63_64
# [-0.38650513 -0.0741502   0.0322412  ...  0.01369339  0.01290478
#   0.01257822]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      0   R-squared:                       0.596
# Model:                            OLS   Adj. R-squared:                  0.594
# Method:                 Least Squares   F-statistic:                     250.3
# Date:                Sat, 12 May 2018   Prob (F-statistic):               0.00
# Time:                        21:52:34   Log-Likelihood:                -2895.4
# No. Observations:                2048   AIC:                             5815.
# Df Residuals:                    2036   BIC:                             5882.
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 0              0.0278      0.024      1.137      0.256      -0.020       0.076
# 1              0.5080      0.019     27.226      0.000       0.471       0.545
# 2              1.2326      0.069     17.806      0.000       1.097       1.368
# 3             -0.1548      0.091     -1.698      0.090      -0.334       0.024
# 4             -0.9928      0.024    -40.847      0.000      -1.040      -0.945
# 5              0.1604      0.034      4.750      0.000       0.094       0.227
# 6             -0.0751      0.023     -3.286      0.001      -0.120      -0.030
# 7             -0.1120      0.032     -3.520      0.000      -0.174      -0.050
# 8              0.0610      0.050      1.211      0.226      -0.038       0.160
# 9              0.0572      0.023      2.471      0.014       0.012       0.103
# 10             0.0039      0.032      0.123      0.902      -0.058       0.066
# 11             0.0652      0.033      1.972      0.049       0.000       0.130
# ==============================================================================
# Omnibus:                     2695.528   Durbin-Watson:                   2.590
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1685592.640
# Skew:                          -6.711   Prob(JB):                         0.00
# Kurtosis:                     142.903   Cond. No.                         5.12
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# r-squared value:  0.5960441273987581
# [61, 62, 64, 65]
# degree of significance, alpha is: 1e-05
# --results--
# [61, 62, 63, 64]
# [61, 62, 64, 65]
# ===========
# [4, 4, 3, 1, 1]
# 4
# 1
# C4_60_62_66_67
# [-0.71810913 -0.67375801 -0.79487346 ... -0.02015014 -0.01972396
#  -0.01977194]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      0   R-squared:                       0.637
# Model:                            OLS   Adj. R-squared:                  0.635
# Method:                 Least Squares   F-statistic:                     297.9
# Date:                Sat, 12 May 2018   Prob (F-statistic):               0.00
# Time:                        21:52:36   Log-Likelihood:                -3602.7
# No. Observations:                2048   AIC:                             7229.
# Df Residuals:                    2036   BIC:                             7297.
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 0              1.1059      0.035     31.999      0.000       1.038       1.174
# 1             -0.0960      0.026     -3.642      0.000      -0.148      -0.044
# 2              0.5053      0.098      5.167      0.000       0.313       0.697
# 3              0.3277      0.129      2.545      0.011       0.075       0.580
# 4              0.1545      0.034      4.501      0.000       0.087       0.222
# 5              0.0363      0.048      0.760      0.447      -0.057       0.130
# 6             -1.3391      0.032    -41.467      0.000      -1.402      -1.276
# 7             -1.1580      0.045    -25.775      0.000      -1.246      -1.070
# 8              0.0194      0.071      0.273      0.785      -0.120       0.159
# 9             -0.0606      0.033     -1.855      0.064      -0.125       0.003
# 10            -0.0092      0.045     -0.205      0.838      -0.097       0.079
# 11            -0.0090      0.047     -0.193      0.847      -0.101       0.083
# ==============================================================================
# Omnibus:                     3828.012   Durbin-Watson:                   2.160
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         20241930.923
# Skew:                         -13.086   Prob(JB):                         0.00
# Kurtosis:                     489.338   Cond. No.                         5.12
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# r-squared value:  0.6371411817057115
# [60, 62, 64, 66, 67]
# degree of significance, alpha is: 1e-05
# --results--
# [60, 62, 66, 67]
# [60, 62, 64, 66, 67]
# ===========
# [4, 5, 4, 1, 0]
# 4
# 1
# C4_61_63_68_69
# [-1.90658569 -1.72347737 -1.7496098  ...  0.00698931  0.00626708
#   0.00679342]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      0   R-squared:                       0.450
# Model:                            OLS   Adj. R-squared:                  0.447
# Method:                 Least Squares   F-statistic:                     138.7
# Date:                Sat, 12 May 2018   Prob (F-statistic):          1.12e-253
# Time:                        21:52:38   Log-Likelihood:                -3688.0
# No. Observations:                2048   AIC:                             7400.
# Df Residuals:                    2036   BIC:                             7468.
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 0              0.1731      0.036      4.805      0.000       0.102       0.244
# 1              1.0235      0.027     37.250      0.000       0.970       1.077
# 2              1.1987      0.102     11.759      0.000       0.999       1.399
# 3             -0.8793      0.134     -6.550      0.000      -1.143      -0.616
# 4              0.2292      0.036      6.405      0.000       0.159       0.299
# 5              0.1817      0.050      3.653      0.000       0.084       0.279
# 6             -0.1008      0.034     -2.993      0.003      -0.167      -0.035
# 7              0.0897      0.047      1.915      0.056      -0.002       0.182
# 8              0.0400      0.074      0.539      0.590      -0.106       0.186
# 9             -0.2909      0.034     -8.541      0.000      -0.358      -0.224
# 10            -0.0841      0.047     -1.797      0.073      -0.176       0.008
# 11             0.0277      0.049      0.569      0.569      -0.068       0.123
# ==============================================================================
# Omnibus:                     3784.164   Durbin-Watson:                   2.006
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         12710881.370
# Skew:                         -12.952   Prob(JB):                         0.00
# Kurtosis:                     388.077   Cond. No.                         5.12
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# r-squared value:  0.44984361062195766
# [60, 61, 62, 63, 64, 69]
# degree of significance, alpha is: 1e-05
# --results--
# [61, 63, 68, 69]
# [60, 61, 62, 63, 64, 69]
# ===========
# [4, 6, 3, 3, 1]
# 4
# 1
# C4_60_62_68_69
# [-1.17001343 -1.09052177 -1.11819496 ...  0.00136454  0.00148878
#   0.00183772]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      0   R-squared:                       0.542
# Model:                            OLS   Adj. R-squared:                  0.539
# Method:                 Least Squares   F-statistic:                     200.8
# Date:                Sat, 12 May 2018   Prob (F-statistic):               0.00
# Time:                        21:52:41   Log-Likelihood:                -3471.5
# No. Observations:                2048   AIC:                             6967.
# Df Residuals:                    2036   BIC:                             7034.
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 0              0.2321      0.032      7.159      0.000       0.168       0.296
# 1             -0.0633      0.025     -2.559      0.011      -0.112      -0.015
# 2             -1.4578      0.092    -15.896      0.000      -1.638      -1.278
# 3              0.3254      0.121      2.694      0.007       0.089       0.562
# 4              0.0585      0.032      1.817      0.069      -0.005       0.122
# 5              0.0727      0.045      1.624      0.104      -0.015       0.160
# 6             -0.0412      0.030     -1.359      0.174      -0.101       0.018
# 7              0.0531      0.042      1.260      0.208      -0.030       0.136
# 8              2.0361      0.067     30.496      0.000       1.905       2.167
# 9              1.1621      0.031     37.920      0.000       1.102       1.222
# 10             0.0338      0.042      0.803      0.422      -0.049       0.116
# 11            -0.0638      0.044     -1.457      0.145      -0.150       0.022
# ==============================================================================
# Omnibus:                     1231.722   Durbin-Watson:                   2.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1040389.290
# Skew:                           1.385   Prob(JB):                         0.00
# Kurtosis:                     113.383   Cond. No.                         5.12
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# r-squared value:  0.5420385448690689
# [60, 62, 68, 69]
# degree of significance, alpha is: 1e-05
# --results--
# [60, 62, 68, 69]
# [60, 62, 68, 69]
# ===========
# [4, 4, 4, 0, 0]
# 3
# 1
# C4_61_65_69_x
# [-0.32507324 -0.20107208 -0.30751322 ... -0.02086369 -0.02018077
#  -0.02066724]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      0   R-squared:                       0.771
# Model:                            OLS   Adj. R-squared:                  0.770
# Method:                 Least Squares   F-statistic:                     572.7
# Date:                Sat, 12 May 2018   Prob (F-statistic):               0.00
# Time:                        21:52:43   Log-Likelihood:                -2589.8
# No. Observations:                2048   AIC:                             5204.
# Df Residuals:                    2036   BIC:                             5271.
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 0             -0.0118      0.021     -0.562      0.574      -0.053       0.029
# 1             -1.0145      0.016    -63.125      0.000      -1.046      -0.983
# 2             -0.2122      0.060     -3.558      0.000      -0.329      -0.095
# 3              0.2646      0.079      3.370      0.001       0.111       0.419
# 4             -0.0131      0.021     -0.626      0.531      -0.054       0.028
# 5             -0.8190      0.029    -28.151      0.000      -0.876      -0.762
# 6             -0.0034      0.020     -0.173      0.863      -0.042       0.035
# 7              0.0360      0.027      1.313      0.189      -0.018       0.090
# 8              0.6940      0.043     15.986      0.000       0.609       0.779
# 9             -0.7959      0.020    -39.944      0.000      -0.835      -0.757
# 10             0.0453      0.027      1.654      0.098      -0.008       0.099
# 11            -0.0154      0.028     -0.543      0.587      -0.071       0.040
# ==============================================================================
# Omnibus:                      862.845   Durbin-Watson:                   2.006
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           412637.544
# Skew:                          -0.577   Prob(JB):                         0.00
# Kurtosis:                      72.529   Cond. No.                         5.12
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# r-squared value:  0.7714659794770988
# [61, 65, 68, 69]
# degree of significance, alpha is: 1e-05
# --results--
# [61, 65, 69]
# [61, 65, 68, 69]
# ===========
# [3, 4, 3, 1, 0]
# 4
# 1
# C4_63_65_66_69
# [-1.18771362 -1.12374178 -1.32491676 ... -0.02043575 -0.02065193
#  -0.02052191]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      0   R-squared:                       0.716
# Model:                            OLS   Adj. R-squared:                  0.715
# Method:                 Least Squares   F-statistic:                     428.5
# Date:                Sat, 12 May 2018   Prob (F-statistic):               0.00
# Time:                        21:52:46   Log-Likelihood:                -3109.6
# No. Observations:                2048   AIC:                             6243.
# Df Residuals:                    2036   BIC:                             6311.
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 0              0.0347      0.027      1.279      0.201      -0.019       0.088
# 1             -0.0036      0.021     -0.173      0.862      -0.044       0.037
# 2             -0.7860      0.077    -10.227      0.000      -0.937      -0.635
# 3              1.8777      0.101     18.552      0.000       1.679       2.076
# 4             -0.1365      0.027     -5.058      0.000      -0.189      -0.084
# 5              1.5051      0.037     40.139      0.000       1.432       1.579
# 6              0.5624      0.025     22.156      0.000       0.513       0.612
# 7             -0.0262      0.035     -0.742      0.458      -0.095       0.043
# 8             -0.2582      0.056     -4.615      0.000      -0.368      -0.149
# 9              1.2634      0.026     49.193      0.000       1.213       1.314
# 10            -0.0147      0.035     -0.416      0.677      -0.084       0.055
# 11             0.0221      0.037      0.602      0.547      -0.050       0.094
# ==============================================================================
# Omnibus:                     2575.377   Durbin-Watson:                   2.038
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1307899.938
# Skew:                           6.202   Prob(JB):                         0.00
# Kurtosis:                     126.179   Cond. No.                         5.12
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# r-squared value:  0.7163402906742148
# [62, 63, 64, 65, 66, 68, 69]
# degree of significance, alpha is: 1e-05
# --results--
# [63, 65, 66, 69]
# [62, 63, 64, 65, 66, 68, 69]
# ===========
# [4, 7, 4, 3, 0]
# 2
# 1
# C4_62_67_x_x
# [-0.34817505 -0.25095064 -0.27075611 ... -0.00379852 -0.00352614
#  -0.00304118]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      0   R-squared:                       0.327
# Model:                            OLS   Adj. R-squared:                  0.323
# Method:                 Least Squares   F-statistic:                     82.26
# Date:                Sat, 12 May 2018   Prob (F-statistic):          5.82e-165
# Time:                        21:52:48   Log-Likelihood:                -3756.6
# No. Observations:                2048   AIC:                             7537.
# Df Residuals:                    2036   BIC:                             7605.
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 0              0.0309      0.037      0.830      0.407      -0.042       0.104
# 1              0.1315      0.028      4.630      0.000       0.076       0.187
# 2              0.4921      0.105      4.668      0.000       0.285       0.699
# 3             -0.4236      0.139     -3.052      0.002      -0.696      -0.151
# 4             -0.0896      0.037     -2.420      0.016      -0.162      -0.017
# 5             -0.0708      0.051     -1.377      0.169      -0.172       0.030
# 6             -0.0197      0.035     -0.565      0.572      -0.088       0.049
# 7              1.4743      0.048     30.438      0.000       1.379       1.569
# 8             -0.0165      0.077     -0.214      0.830      -0.167       0.134
# 9              0.0717      0.035      2.036      0.042       0.003       0.141
# 10             0.0222      0.048      0.458      0.647      -0.073       0.117
# 11             0.0047      0.050      0.094      0.925      -0.094       0.103
# ==============================================================================
# Omnibus:                     4500.433   Durbin-Watson:                   2.243
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         26273737.847
# Skew:                          19.304   Prob(JB):                         0.00
# Kurtosis:                     556.538   Cond. No.                         5.12
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# r-squared value:  0.3265341255777183
# [61, 62, 67]
# degree of significance, alpha is: 1e-05
# --results--
# [62, 67]
# [61, 62, 67]
# ===========
# [2, 3, 2, 1, 0]
# 4
# 1
# C4_60_61_66_67
# [ 1.22198486e+00  1.29470580e+00  1.13822547e+00 ... -3.03264552e-04
#  -1.24892488e-05 -2.07303001e-04]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      0   R-squared:                       0.761
# Model:                            OLS   Adj. R-squared:                  0.760
# Method:                 Least Squares   F-statistic:                     540.7
# Date:                Sat, 12 May 2018   Prob (F-statistic):               0.00
# Time:                        21:52:51   Log-Likelihood:                -3119.1
# No. Observations:                2048   AIC:                             6262.
# Df Residuals:                    2036   BIC:                             6330.
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 0             -0.9072      0.027    -33.240      0.000      -0.961      -0.854
# 1             -1.0658      0.021    -51.212      0.000      -1.107      -1.025
# 2              0.0446      0.077      0.578      0.563      -0.107       0.196
# 3              0.0667      0.102      0.656      0.512      -0.133       0.266
# 4              0.0410      0.027      1.512      0.131      -0.012       0.094
# 5              0.0121      0.038      0.322      0.747      -0.062       0.086
# 6             -0.1575      0.026     -6.176      0.000      -0.208      -0.107
# 7             -2.0218      0.035    -56.985      0.000      -2.091      -1.952
# 8              0.6012      0.056     10.695      0.000       0.491       0.711
# 9              0.0192      0.026      0.743      0.458      -0.031       0.070
# 10            -0.0642      0.035     -1.811      0.070      -0.134       0.005
# 11             0.1077      0.037      2.921      0.004       0.035       0.180
# ==============================================================================
# Omnibus:                      928.746   Durbin-Watson:                   1.910
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1226417.897
# Skew:                           0.481   Prob(JB):                         0.00
# Kurtosis:                     122.880   Cond. No.                         5.12
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# r-squared value:  0.7611506694649461
# [60, 61, 66, 67, 68]
# degree of significance, alpha is: 1e-05
# --results--
# [60, 61, 66, 67]
# [60, 61, 66, 67, 68]
# ===========
# [4, 5, 4, 1, 0]
# 4
# 1
# C4_64_66_67_70
# --------------------------------------
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-41-d41d9ae12c4b> in <module>()
#       1 # Do not uncomment this, this is a helper notebook not supposed to run this.
#       2 if __name__ == '__main__':
# ----> 3     test_function_accuracy(lg_regression, plotting=False, deleting=True)
#
# <ipython-input-10-b6f753328d86> in test_function_accuracy(note_detection_function_to_test, plotting, deleting)
#      27                                                com, midi_instructions,
#      28                                                plotting = plotting,
# ---> 29                                                deleting = deleting)
#      30         notes_present = len(com)
#      31         notes_detected = len(result)
#
# <ipython-input-10-52e5185ae8da> in test_function_accuracy_single(note_detection_function_to_test, com, midi_instructions, plotting, deleting)
#      11
#      12     # convert midi file to signal
# ---> 13     signal = convert_midi_to_signal(filename)
#      14
#      15     if plotting:
#
# <ipython-input-10-580ccd4729ad> in convert_midi_to_signal(filename)
#      10     subprocess.run("fluidsynth -F soundfile_sch/{}.wav {} midifile_sch/{}.mid"
#      11                    .format(filename,soundfont_dir,filename),shell=True)
# ---> 12     sleep(1)
#      13     audio,sr = sf.read("soundfile_sch/{}.wav".format(filename))
#      14     if type(audio[0]) != float or type(audio[0]) != int:
#
# KeyboardInterrupt:
